# %% [markdown]
# # Web Scraping Use Case: News Articles
#
# The code below was used as part of a project that required scraping news articles from different Filipino news websites. This script in particular was used to scrape opinion pieces from The Philippine Star.

# %%
from selenium import webdriver
from time import sleep
import re
import numpy as np
import pandas as pd
from selenium.webdriver.common.keys import Keys
import requests
from bs4 import BeautifulSoup as soup
from selenium.webdriver.chrome.options import Options
import random
import os
from IPython.display import clear_output
import matplotlib.pyplot as plt

# %% [markdown]
# ## Setting up a Proxy
#
# You might want to set up a proxy as sampled below to prevent your actual IP from being blocked by the website you're scraping. The IPs below are just placeholders.

# %%
os.environ['HTTP_PROXY'] = 'http://54.238.250.91:8080/'
os.environ['HTTPS_PROXY'] = 'https://54.238.250.91:8080/'

# %% [markdown]
# ### Initialize driver object
#
# You'll be initializing a driver object to use `Selenium`. Just google `<Your Brower Name Here> Driver` and you should probably get a bunch of download options. Just check your browser settings for the version number and then download the equivalent driver version. Place the driver file in the same folder as your notebook.

# %%
opts = Options()
opts.add_argument("user-agent=Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1)\
        AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 \
        Safari/537.36")


# This one for headlines
driver = webdriver.Chrome('chromedriver', options=opts)
driver.get('https://www.philstar.com/opinion')

# %% [markdown]
# # Using Selenium
#
# Selenium is helpful for websites with dynamic HTML structures, such as continuously scrolling ones, or ones with multiple pop-up and hover-over types of things. You can interact with objects through different means in the web driver. For example, `find_element_by_css_selector` allows us to select a headline by using its css selector.

# %%
# driver.find_element_by_css_selector('div.profileCard__header__info')
driver.find_element_by_css_selector('div.news_title').text
# Out:
# 'Seven deadly sins of leadership'

# %% [markdown]
# # Using BeautifulSoup
#
# For this use case, we only use Selenium to manually scroll through and load all available archived news articles in the opinion section of the website. It's more practical to use BeautifulSoup to select the items we need to get from the web page. We will be extracting the headline, link, date, and text of each opinion piece.

# %%
page_html = soup(driver.page_source, "lxml")

# %% [markdown]
# Below are fairly straightforward examples of using `BeautifulSoup` to select objects we are interested in. `.select` generates a list object, so we index the first element to show a sample of the

# %%
page_html.select('div.news_title > a')[0].get('href')
# Out:
# 'https://www.philstar.com/opinion/2019/08/18/1944271/seven-deadly-sins-leadership'

# %%
page_html.select('div.news_title > a')[0].text
# Out:
# 'Seven deadly sins of leadership'

# %% [markdown]
# Once we're sure about the selected objects, store them into lists.

# %%
k = page_html.select('div.news_title > a')

links = []
heads = []

for elem in k:
    links.append(elem.get('href'))
    heads.append(elem.text)

# %% [markdown]
# Use regular expressions to extract the dates from the links.

# %%
dates = re.findall(r"/(\d{4}/\d{2}/\d{2})", str(links))

# %%
# Just making sure all lengths are equal
len(links), len(heads), len(dates)
# Out:
# (214, 214, 214)

# %%
op_data = pd.DataFrame({"headlines": heads, "links": links, "dates": dates})

# %%
op_data.head()
# Out:
#                                            headlines  \
# 0                    Seven deadly sins of leadership
# 1              Aftershock of the colonial earthquake
# 2           Clark airport placed under private group
# 3                Tightening US-Philippines relations
# 4  Diabetes – high rate of med discontinuation re...
#
#                                                links       dates
# 0  https://www.philstar.com/opinion/2019/08/18/19...  2019/08/18
# 1  https://www.philstar.com/opinion/2019/08/18/19...  2019/08/18
# 2  https://www.philstar.com/opinion/2019/08/18/19...  2019/08/18
# 3  https://www.philstar.com/opinion/2019/08/18/19...  2019/08/18
# 4  https://www.philstar.com/opinion/2019/08/18/19...  2019/08/18

# %% [markdown]
# # Getting the text
#
# Note that at this point, we still don't have the bodies of text associated with each headline. We extracted the links per headline precisely for this reason: we will access each link in the list we generated earlier and extract the text. The output list will then be appended as a column in a new dataframe.

# %%
def get_html(url):
    """ Return soup object of given webpage. """
    headers = {
        'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1)\
        AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 \
        Safari/537.36'}
    p = requests.get(url, headers=headers)
    sp = soup(p.text, 'html.parser')
    p.close
    return sp

# %% [markdown]
# note: `get_text` appends to a specific list, `arts`, which I initialize after defining the function.

# %%
def get_text(links, lim=5):
    """
    Accepts a list of links and extracts the main body of text from
    each accessed link. 
    
    Parameters
    ----------
    links : list
        list of links to access
    """
    lim = lim
#     stopper = 0
    
    for url in links:
#         if stopper == lim:
#             break
        try:
            sp = get_html(url)
        except:
            print('cannot find url')
        
        try:
            # yes, they are tagged sports articles for some reason
            texts = sp.select('#sports_article_writeup')[0].text
            arts.append(texts)
        except:
            arts.append('something went wrong')
        
#         stopper += 1
        sleeptime = random.randint(5,9)
        sleep(sleeptime)

# %%
arts = []

# %%
get_text(links)

# %%
op_data = pd.DataFrame({"headlines": heads, "links": links, "dates": dates, "text": arts})

# %%
op_data.to_csv("Philstar_Opinion.csv")

# %% [markdown]
# # Sample Output

# %%
op_data
# Out:
#                                              headlines  \
# 0                      Seven deadly sins of leadership
# 1                Aftershock of the colonial earthquake
# 2             Clark airport placed under private group
# 3                  Tightening US-Philippines relations
# 4    Diabetes – high rate of med discontinuation re...
# 5    Petition denied based on petitioner’s prior fi...
# 6                                               Choppy
# 7                   AFP, PNP resurrect creepy memories
# 8                           The young and the restless
# 9                           The sun of the imagination
# 10               Aftershock of the colonial earthquake
# 11   Tawi-Tawi fishermen confirm sightings of Chine...
# 12   Chinese survey ship back in Vietnam-claimed wa...
# 13          Duterte bent on raising SCS ruling with Xi
# 14   Palace OK with seeking US help to monitor Chin...
# 15                          The sun of the imagination
# 16             Duterte can lower target in China talks
# 17             Walking the coastal path - A meditation
# 18          ‘Crazy’ ideas to unravel traffic gridlocks
# 19                                             Plunder
# 20              Poor to suffer most with death penalty
# 21             Farm tourism is fast becoming a reality
# 22                                 Catching catcallers
# 23                                       No to plastic
# 24                         Panama City turns 500 years
# 25                      US military mightier than ever
# 26              Poor to suffer most with death penalty
# 27                         EDITORIAL - SONA guideposts
# 28                        EDITORIAL - ‘Modern slavery’
# 2    \nCLARK FREEPORT – Management of Clark Interna...
# 3    \nThe recent signing of a memorandum of unders...
# 4    \nMost patients with type 2 diabetes mellitus ...
# 5    \nMany people believe that once they obtain a ...
# 6    \nThe New York Stock Exchange (NYSE) lost 800 ...
# 7    \nOn Dec. 4, 2018, President Duterte signed Ex...
# 8    \nThe world is spellbound by the Hong Kong rio...
# 9    \nIn the popular mind, to be a poet means to b...
# 10   \nIf you watch the violent demonstration in Ho...
# 11   \nZAMBOANGA CITY, Philippines — Fishermen said...
# 12   \nHANOI, Vietnam — A Chinese survey vessel has...
# 13   \nMANILA, Philippines — China’s refusal to rec...
# 14   \nMANILA, Philippines — Malacañang is open to ...
# 15   \nIn the popular mind, to be a poet means to b...
# 16   \nWith China saying in advance that President ...
# 17   \nBUDE, England – Alone and at peace, I stand ...
# 18   \nTraffic gridlocks in Metro Manila will turn ...
# 19   \nIn the deliberation regarding the restoratio...
# 20   \nWITH our flawed justice system, it would be ...
# 21   \nI had a call from former Tourism secretary M...
# 22   \nA friend of mine in her late 50s told me she...
# 23   \n"We know how long it takes most kinds of lea...
# 24   \nToday, I join my countrymen in celebrating t...
# 25   \nAt the advent of the Trump administration, t...
# 26   \nWITH our flawed justice system, it would be ...
# 27   \nJobs, wages and consumer prices are the prin...
# 28   \nIf the government wants evidence of worker a...
# 29   \nI had a call from former Tourism secretary M...
# ..                                                 ...
# 184  \nAs expected, the president’s decision to vet...
# 185  \nRecently, the State Department revised immig...
# 186  \nCatholic bishops have called for prayers whi...
# 187  \nIf you are one of those who will seriously b...
# 188  \nAs a woman who loves to celebrate the succes...
# 189  \nImagine a crisis in which the Philippines wa...
# 190  \nIt is not surprising that domestic news is f...
# 191  \nIn last Monday’s SONA, President Rodrigo Dut...
# 192  \nAt least some government officials sounded t...
# 193  \nAt a meeting of the Center for Disease Contr...
# 194  \nUS authorities interdicted the biggest shipm...
# 195  \nI’ve had numerous consultations over the yea...
# 196  \nWorld Bank economist Dr. Rong Qian said in a...
# 197  \nAs he promised, President Duterte on Thursda...
# 198  \nThe procurement of P77.26 million worth of n...
# 199  \nNearly half of patients in the general popul...
# 200  \nDuring the meeting between President Duterte...
# 201  \nNobody can deny that Duterte is moving heave...
# 202  \nMany people believe that once their case is ...
# 203  \nThe Vatican sex abuse summit, officially cal...
# 204  \nIs it really surprising that all – if not mo...
# 205  \nInvestors have been expressing concern for m...
# 206  \nToday I lend this space to earth lawyer Tony...
# 207  \nAs that statement from the National Press Cl...
# 208  \nIt may sound ridiculous but election-related...
# 209  \nThere’s an upside to the continuing squabble...
# 210  \nIt is saddening that the casualty count from...
# 211  \n"Children exist in the world as well as in t...
# 212  \nGo For It! The Metro Manila Development Auth...
# 213  \nEven as health officials are still trying to...
#
# [214 rows x 4 columns]
